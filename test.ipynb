# %%
import requests

url = "https://apis.openapi.sk.com/puzzle/subway/congestion/stat/train/stations/129?dow=MON&hh=08&"
# 515: 역사코드
# dow: 요일
# hh: 시간

headers = {
    "accept": "application/json",
    "Content-Type": "application/json",
    "appkey": "MsOyI3zoR81u08mIfLmQo5qyOqloYBgA1tAQRCou"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"status":{"code":"00","message":"success","totalCount":1},"contents":{"subwayLine":"1호선","stationName":"종로5가역","stationCode":"129","stat":[{"startStationCode":"100","startStationName":"소요산역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":57},{"dow":"MON","hh":"08","mm":"10","congestionTrain":114},{"dow":"MON","hh":"08","mm":"20","congestionTrain":114},{"dow":"MON","hh":"08","mm":"30","congestionTrain":114},{"dow":"MON","hh":"08","mm":"40","congestionTrain":57},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"100","startStationName":"소요산역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":107},{"dow":"MON","hh":"08","mm":"10","congestionTrain":107},{"dow":"MON","hh":"08","mm":"20","congestionTrain"
# ...

# %%
response.text
# Out:
# '{"status":{"code":"00","message":"success","totalCount":1},"contents":{"subwayLine":"5호선","stationName":"발산역","stationCode":"515","stat":[{"startStationCode":"510","startStationName":"방화역","endStationCode":"517","endStationName":"화곡역","prevStationCode":"514","prevStationName":"마곡역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"510","startStationName":"방화역","endStationCode":"530","endStationName":"애오개역","prevStationCode":"514","prevStationName":"마곡역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON"
# ...

# %%
import json

# %%
response.text
# Out:
# '{"status":{"code":"00","message":"success","totalCount":1},"contents":{"subwayLine":"5호선","stationName":"발산역","stationCode":"515","stat":[{"startStationCode":"510","startStationName":"방화역","endStationCode":"517","endStationName":"화곡역","prevStationCode":"514","prevStationName":"마곡역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"510","startStationName":"방화역","endStationCode":"530","endStationName":"애오개역","prevStationCode":"514","prevStationName":"마곡역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON"
# ...

# %%
import json
import pandas as pd

def preporcessing(response_string):
    # Your JSON response string
    # response_string = response.text

    # Parse the JSON string into a Python dictionary
    response_dict = json.loads(response_string)

    # Extracting data
    data_list = []
    for stat_entry in response_dict['contents']['stat']:
        start_station_name = stat_entry['startStationName']
        end_station_name = stat_entry['endStationName']
        prevStationName = stat_entry["prevStationName"]

        for data_entry in stat_entry['data']:
            dow = data_entry['dow']
            hh = data_entry['hh']
            mm = data_entry['mm']
            congestion_train = data_entry['congestionTrain']

            data_list.append([start_station_name, end_station_name, prevStationName, dow, f"{hh}:{mm}", congestion_train])

    # Creating the DataFrame
    columns = ['Start Station', 'End Station', "prevStationName" , 'Day of Week', 'Time', 'Congestion']
    df = pd.DataFrame(data_list, columns=columns)

    # Printing the DataFrame
    return df

# %%
df = preporcessing(response.text)
df
# Out:
#     Start Station End Station prevStationName Day of Week   Time  Congestion
# 0            소요산역         구로역            동대문역         MON  08:00          57
# 1            소요산역         구로역            동대문역         MON  08:10         114
# 2            소요산역         구로역            동대문역         MON  08:20         114
# 3            소요산역         구로역            동대문역         MON  08:30         114
# 4            소요산역         구로역            동대문역         MON  08:40          57
# ..            ...         ...             ...         ...    ...         ...
# 343           신창역        청량리역           종로3가역         MON  08:10           0
# 344           신창역        청량리역           종로3가역         MON  08:20           0
# 345           신창역        청량리역           종로3가역         MON  08:30           0
# 346           신창역        청량리역           종로3가역         MON  08:40           0
# 347           신창역        청량리역           종로3가역         MON  08:50           0
#
# [348 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Start Station    12 non-null     object
#  1   End Station      12 non-null     object
#  2   prevStationName  12 non-null     object
#  3   Day of Week      12 non-null     object
#  4   Time             12 non-null     object
#  5   Congestion       12 non-null     int64
# dtypes: int64(1), object(5)
# memory usage: 704.0+ bytes

# %%
text = '{"status":{"code":"00","message":"success","totalCount":1},"contents":{"subwayLine":"1호선","stationName":"종로5가역","stationCode":"129","stat":[{"startStationCode":"100","startStationName":"소요산역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":60},{"dow":"MON","hh":"08","mm":"10","congestionTrain":119},{"dow":"MON","hh":"08","mm":"20","congestionTrain":119},{"dow":"MON","hh":"08","mm":"30","congestionTrain":119},{"dow":"MON","hh":"08","mm":"40","congestionTrain":60},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"100","startStationName":"소요산역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":112},{"dow":"MON","hh":"08","mm":"10","congestionTrain":112},{"dow":"MON","hh":"08","mm":"20","congestionTrain":112},{"dow":"MON","hh":"08","mm":"30","congestionTrain":112},{"dow":"MON","hh":"08","mm":"40","congestionTrain":112},{"dow":"MON","hh":"08","mm":"50","congestionTrain":80}]},{"startStationCode":"101","startStationName":"동두천역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"101","startStationName":"동두천역","endStationCode":"152","endStationName":"부평역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":71},{"dow":"MON","hh":"08","mm":"20","congestionTrain":142},{"dow":"MON","hh":"08","mm":"30","congestionTrain":142},{"dow":"MON","hh":"08","mm":"40","congestionTrain":101},{"dow":"MON","hh":"08","mm":"50","congestionTrain":67}]},{"startStationCode":"101","startStationName":"동두천역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":114},{"dow":"MON","hh":"08","mm":"10","congestionTrain":114},{"dow":"MON","hh":"08","mm":"20","congestionTrain":92},{"dow":"MON","hh":"08","mm":"30","congestionTrain":92},{"dow":"MON","hh":"08","mm":"40","congestionTrain":72},{"dow":"MON","hh":"08","mm":"50","congestionTrain":72}]},{"startStationCode":"101","startStationName":"동두천역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":52},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":38},{"dow":"MON","hh":"08","mm":"50","congestionTrain":76}]},{"startStationCode":"107","startStationName":"양주역","endStationCode":"133","endStationName":"서울역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"107","startStationName":"양주역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"107","startStationName":"양주역","endStationCode":"152","endStationName":"부평역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":117},{"dow":"MON","hh":"08","mm":"10","congestionTrain":122},{"dow":"MON","hh":"08","mm":"20","congestionTrain":122},{"dow":"MON","hh":"08","mm":"30","congestionTrain":61},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"107","startStationName":"양주역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":61},{"dow":"MON","hh":"08","mm":"10","congestionTrain":122},{"dow":"MON","hh":"08","mm":"20","congestionTrain":122},{"dow":"MON","hh":"08","mm":"30","congestionTrain":110},{"dow":"MON","hh":"08","mm":"40","congestionTrain":106},{"dow":"MON","hh":"08","mm":"50","congestionTrain":81}]},{"startStationCode":"110","startStationName":"의정부역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"110","startStationName":"의정부역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"110","startStationName":"의정부역","endStationCode":"P157-1","endStationName":"서동탄역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":112},{"dow":"MON","hh":"08","mm":"10","congestionTrain":56},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"116","startStationName":"창동역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"119","startStationName":"광운대역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"119","startStationName":"광운대역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"119","startStationName":"광운대역","endStationCode":"P157","endStationName":"병점역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"119","startStationName":"광운대역","endStationCode":"P157-1","endStationName":"서동탄역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":109},{"dow":"MON","hh":"08","mm":"10","congestionTrain":109},{"dow":"MON","hh":"08","mm":"20","congestionTrain":113},{"dow":"MON","hh":"08","mm":"30","congestionTrain":103},{"dow":"MON","hh":"08","mm":"40","congestionTrain":93},{"dow":"MON","hh":"08","mm":"50","congestionTrain":54}]},{"startStationCode":"119","startStationName":"광운대역","endStationCode":"P169","endStationName":"천안역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"119","startStationName":"광운대역","endStationCode":"P177","endStationName":"신창역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":114},{"dow":"MON","hh":"08","mm":"10","congestionTrain":57},{"dow":"MON","hh":"08","mm":"20","congestionTrain":58},{"dow":"MON","hh":"08","mm":"30","congestionTrain":115},{"dow":"MON","hh":"08","mm":"40","congestionTrain":115},{"dow":"MON","hh":"08","mm":"50","congestionTrain":88}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"133","endStationName":"서울역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"141","endStationName":"구로역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"P157-1","endStationName":"서동탄역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":57},{"dow":"MON","hh":"08","mm":"10","congestionTrain":57},{"dow":"MON","hh":"08","mm":"20","congestionTrain":28},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"P169","endStationName":"천안역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":17},{"dow":"MON","hh":"08","mm":"40","congestionTrain":34},{"dow":"MON","hh":"08","mm":"50","congestionTrain":34}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"P169","endStationName":"천안역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":61},{"dow":"MON","hh":"08","mm":"10","congestionTrain":61},{"dow":"MON","hh":"08","mm":"20","congestionTrain":65},{"dow":"MON","hh":"08","mm":"30","congestionTrain":70},{"dow":"MON","hh":"08","mm":"40","congestionTrain":64},{"dow":"MON","hh":"08","mm":"50","congestionTrain":64}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"P177","endStationName":"신창역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"124","startStationName":"청량리역","endStationCode":"P177","endStationName":"신창역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"127","startStationName":"동묘앞역","endStationCode":"161","endStationName":"인천역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"127","startStationName":"동묘앞역","endStationCode":"P157-1","endStationName":"서동탄역","prevStationCode":"128","prevStationName":"동대문역","updnLine":1,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"133","startStationName":"서울역","endStationCode":"107","endStationName":"양주역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"133","startStationName":"서울역","endStationCode":"110","endStationName":"의정부역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"133","startStationName":"서울역","endStationCode":"119","endStationName":"광운대역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"133","startStationName":"서울역","endStationCode":"127","endStationName":"동묘앞역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"141","startStationName":"구로역","endStationCode":"101","endStationName":"동두천역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"141","startStationName":"구로역","endStationCode":"107","endStationName":"양주역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"141","startStationName":"구로역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"152","startStationName":"부평역","endStationCode":"100","endStationName":"소요산역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"152","startStationName":"부평역","endStationCode":"101","endStationName":"동두천역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"100","endStationName":"소요산역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":55},{"dow":"MON","hh":"08","mm":"10","congestionTrain":49},{"dow":"MON","hh":"08","mm":"20","congestionTrain":49},{"dow":"MON","hh":"08","mm":"30","congestionTrain":25},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":17}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"100","endStationName":"소요산역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":26},{"dow":"MON","hh":"08","mm":"20","congestionTrain":54},{"dow":"MON","hh":"08","mm":"30","congestionTrain":54},{"dow":"MON","hh":"08","mm":"40","congestionTrain":36},{"dow":"MON","hh":"08","mm":"50","congestionTrain":18}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"101","endStationName":"동두천역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":42},{"dow":"MON","hh":"08","mm":"10","congestionTrain":50},{"dow":"MON","hh":"08","mm":"20","congestionTrain":50},{"dow":"MON","hh":"08","mm":"30","congestionTrain":47},{"dow":"MON","hh":"08","mm":"40","congestionTrain":44},{"dow":"MON","hh":"08","mm":"50","congestionTrain":50}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"101","endStationName":"동두천역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"107","endStationName":"양주역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":49},{"dow":"MON","hh":"08","mm":"10","congestionTrain":49},{"dow":"MON","hh":"08","mm":"20","congestionTrain":54},{"dow":"MON","hh":"08","mm":"30","congestionTrain":54},{"dow":"MON","hh":"08","mm":"40","congestionTrain":36},{"dow":"MON","hh":"08","mm":"50","congestionTrain":36}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"110","endStationName":"의정부역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":38},{"dow":"MON","hh":"08","mm":"10","congestionTrain":49},{"dow":"MON","hh":"08","mm":"20","congestionTrain":60},{"dow":"MON","hh":"08","mm":"30","congestionTrain":48},{"dow":"MON","hh":"08","mm":"40","congestionTrain":43},{"dow":"MON","hh":"08","mm":"50","congestionTrain":38}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"119","endStationName":"광운대역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"161","startStationName":"인천역","endStationCode":"127","endStationName":"동묘앞역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"P157","startStationName":"병점역","endStationCode":"119","endStationName":"광운대역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":13}]},{"startStationCode":"P157","startStationName":"병점역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":33},{"dow":"MON","hh":"08","mm":"10","congestionTrain":33},{"dow":"MON","hh":"08","mm":"20","congestionTrain":16},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"P157-1","startStationName":"서동탄역","endStationCode":"119","endStationName":"광운대역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":44},{"dow":"MON","hh":"08","mm":"10","congestionTrain":38},{"dow":"MON","hh":"08","mm":"20","congestionTrain":43},{"dow":"MON","hh":"08","mm":"30","congestionTrain":40},{"dow":"MON","hh":"08","mm":"40","congestionTrain":38},{"dow":"MON","hh":"08","mm":"50","congestionTrain":19}]},{"startStationCode":"P157-1","startStationName":"서동탄역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":22},{"dow":"MON","hh":"08","mm":"10","congestionTrain":44},{"dow":"MON","hh":"08","mm":"20","congestionTrain":44},{"dow":"MON","hh":"08","mm":"30","congestionTrain":35},{"dow":"MON","hh":"08","mm":"40","congestionTrain":35},{"dow":"MON","hh":"08","mm":"50","congestionTrain":17}]},{"startStationCode":"P157-1","startStationName":"서동탄역","endStationCode":"127","endStationName":"동묘앞역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":11},{"dow":"MON","hh":"08","mm":"30","congestionTrain":23},{"dow":"MON","hh":"08","mm":"40","congestionTrain":23},{"dow":"MON","hh":"08","mm":"50","congestionTrain":16}]},{"startStationCode":"P169","startStationName":"천안역","endStationCode":"119","endStationName":"광운대역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":29},{"dow":"MON","hh":"08","mm":"10","congestionTrain":29},{"dow":"MON","hh":"08","mm":"20","congestionTrain":42},{"dow":"MON","hh":"08","mm":"30","congestionTrain":42},{"dow":"MON","hh":"08","mm":"40","congestionTrain":21},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"P169","startStationName":"천안역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":10},{"dow":"MON","hh":"08","mm":"40","congestionTrain":22},{"dow":"MON","hh":"08","mm":"50","congestionTrain":22}]},{"startStationCode":"P169","startStationName":"천안역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"P177","startStationName":"신창역","endStationCode":"119","endStationName":"광운대역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":50},{"dow":"MON","hh":"08","mm":"10","congestionTrain":50},{"dow":"MON","hh":"08","mm":"20","congestionTrain":39},{"dow":"MON","hh":"08","mm":"30","congestionTrain":39},{"dow":"MON","hh":"08","mm":"40","congestionTrain":19},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]},{"startStationCode":"P177","startStationName":"신창역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":0,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":10}]},{"startStationCode":"P177","startStationName":"신창역","endStationCode":"124","endStationName":"청량리역","prevStationCode":"130","prevStationName":"종로3가역","updnLine":0,"directAt":1,"data":[{"dow":"MON","hh":"08","mm":"00","congestionTrain":0},{"dow":"MON","hh":"08","mm":"10","congestionTrain":0},{"dow":"MON","hh":"08","mm":"20","congestionTrain":0},{"dow":"MON","hh":"08","mm":"30","congestionTrain":0},{"dow":"MON","hh":"08","mm":"40","congestionTrain":0},{"dow":"MON","hh":"08","mm":"50","congestionTrain":0}]}],"statStartDate":"20230501","statEndDate":"2023073"}}'

df = preporcessing(text)
df.to_csv('/Users/yerin/AIB/udemy/종로5가.csv')

# %%
(df['Start Station'].value_counts()).index
# Out:
# Index(['방화역', '여의도역', '애오개역', '왕십리역', '군자역', '강동역', '상일동역', '하남검단산역', '마천역'], dtype='object', name='Start Station')

# %%
df['End Station'].value_counts()
# Out:
# End Station
# 방화역       48
# 화곡역        6
# 애오개역       6
# 군자역        6
# 상일동역       6
# 하남검단산역     6
# 마천역        6
# Name: count, dtype: int64

# %%
df.to_csv('/Users/yerin/AIB/udemy/songnae.csv')

# %%
(17 * 7 * 449) / 10 / 100
# Out:
# 53.431000000000004

# %%
df.to_csv('/Users/yerin/AIB/udemy/df2.csv')

# %%
code = pd.read_csv('/Users/yerin/AIB/udemy/서울교통공사 노선별 지하철역 정보.csv', encoding='cp949')
code.query('전철역명 == "송내"')
# Out:
#     전철역코드 전철역명 전철명명(영문)    호선 외부코드 전철명명(중문) 전철명명(일문)
# 34   1805   송내  Songnae  01호선  150       松內       松內

# %%
import pandas as pd

subway = pd.read_csv('/Users/yerin/AIB/udemy/dataset/지하철 코드.csv', encoding='cp949')

subway
# Out:
#     전철역코드   전철역명          전철명명(영문)    호선   외부코드    전철명명(중문) 전철명명(일문)
# 0    0244     용답           Yongdap  02호선  211-1          龍踏       龍踏
# 1    0245     신답            Sindap  02호선  211-2          新踏       新踏
# 2    0250     용두            Yongdu  02호선  211-3          龍頭       龍頭
# 3    0336    학여울        Hangnyeoul  03호선    346  Hangnyeoul   ハンニョウル
# 4    0428    삼각지          Samgakji  04호선    428         三角地      三角地
# ..    ...    ...               ...   ...    ...         ...      ...
# 768  0159    동묘앞           Dongmyo  01호선    127          東廟      東廟前
# 769  0200    까치산         Kkachisan  02호선  234-4         喜鵲山      カチ山
# 770  0201     시청         City Hall  02호선    201          市廳       市廳
# 771  0202  을지로입구  Euljiro 1(il)-ga  02호선    202       乙支路入口    乙支路入口
# 772  0300     대곡            Daegok   경의선   K322          大谷       大谷
#
# [773 rows x 7 columns]

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   전철역코드     773 non-null    object
#  1   전철역명      773 non-null    object
#  2   전철명명(영문)  773 non-null    object
#  3   호선        773 non-null    object
#  4   외부코드      773 non-null    object
#  5   전철명명(중문)  742 non-null    object
#  6   전철명명(일문)  732 non-null    object
# dtypes: object(7)
# memory usage: 42.4+ KB

# %%
subway.query('전철역명=="광운대"')
# Out:
#     전철역코드 전철역명         전철명명(영문)    호선  외부코드 전철명명(중문) 전철명명(일문)
# 198  1305  광운대  Kwangwoon Univ.   경춘선  P116      NaN      NaN
# 240  1019  광운대  Kwangwoon Univ.  01호선   119      光云大      光云大

# %%
dic = {}
for row in range(len(subway)):
    dic[subway['전철역코드'].loc[row]] = subway['외부코드'].loc[row]

dic
# Out:
# {'0244': '211-1',
#  '0245': '211-2',
#  '0250': '211-3',
#  '0336': '346',
#  '0428': '428',
#  '0429': '429',
#  '1008': 'K111',
#  '1014': 'K117',
#  '103C': '836',
#  '104C': '837',
#  '1286': 'K336',
#  '1456': '441',
#  '1703': 'P144',
#  '0412': '412',
#  '0417': '417',
#  '102C': 'K210',
#  '1030': 'K221',
#  '1217': 'K135',
#  '1218': 'K136',
#  '1407': 'P176',
#  '1450': '435',
#  '1452': '437',
#  '1455': '440',
#  '1458': '443',
#  '1504': 'K413',
#  '0310': '320',
#  '0319': '329',
#  '0339': '349',
#  '0415': '415',
#  '0425': '425',
#  '100C': 'K110',
#  '1013': 'K116',
#  '1264': 'K314',
#  '1265': 'K315',
#  '1279': 'K330',
#  '1408': 'P177',
#  '1502': 'K411',
#  '1510': 'K419',
#  '1702': 'P142',
#  '1704': 'P145',
#  '1706': 'P147',
#  '1707': 'P148',
#  '1708': 'P149',
#  '1709': 'P150',
#  '1711': 'P153',
#  '1750': 'P144-1',
#  '1761': '455',
#  '1802': '144',
#  '1847': 'K211',
#  '1883': 'K264',
#  '0248': '234-2',
#  '0320': '330',
#  '0327': '337',
# ...

# %%
import pickle

with open('/Users/yerin/AIB/udemy/mapping.pickle','wb') as fw:
    pickle.dump(dic, fw)

# %%
subway['전철역코드'].loc[0]
# Out:
# '0244'

# %%
subway.query('전철역명=="모란"')
# Out:
#     전철역코드 전철역명 전철명명(영문)     호선  외부코드 전철명명(중문) 전철명명(일문)
# 145  1853   모란    Moran  수인분당선  K225       牡丹       牡丹
# 552  2827   모란    Moran   08호선   827       牡丹       牡丹

# %%
subway.value_counts('호선')
# Out:
# 호선
# 01호선       99
# 수인분당선      63
# 경의선        57
# 05호선       56
# 07호선       53
# 04호선       51
# 02호선       51
# 03호선       44
# 06호선       39
# 09호선       38
# 인천선        30
# 인천2호선      27
# 경춘선        25
# 08호선       18
# 서해선        17
# 신분당선       16
# 용인경전철      15
# 의정부경전철     15
# 공항철도       14
# 우이신설경전철    13
# 경강선        11
# 신림선        11
# 김포도시철도     10
# Name: count, dtype: int64

# %%
import pandas as pd
import requests
from urllib.parse import quote

def metrojson():

    SID = '133'  # 출발역 ID (예: 서울역)
    EID = '128'  # 도착역 ID (예: 독립문역)
    Sopt = '1'   # 최단거리(1) 또는 최소환승(2) 설정
    apiKey = "VMlJA4GzIlpVQkHARsMsz6uOKDrPKxiHBCfYXoz6ufo" 

    url = f'https://api.odsay.com/v1/api/subwayPath?lang=0&CID=1000&SID={SID}&EID={EID}&Sopt={Sopt}&apiKey={apiKey}'
    
    res = requests.get(url)
    data = res.json()

    # DataFrame으로 만들 데이터 추출
    globalStartName = data["result"]["globalStartName"]
    globalEndName = data["result"]["globalEndName"]
    globalTravelTime = data["result"]["globalTravelTime"]
    globalDistance = data["result"]["globalDistance"]
    globalStationCount = data["result"]["globalStationCount"]
    fare = data["result"]["fare"]
    cashFare = data["result"]["cashFare"]
    driveInfoSet = data["result"]["driveInfoSet"]
    stationSet = data["result"]["stationSet"]

    # 'driveInfo'와 'stations' 리스트를 DataFrame으로 변환
    drive_info_df = pd.DataFrame(driveInfoSet["driveInfo"])
    stations_df = pd.DataFrame(stationSet["stations"])

    # 결과 데이터를 하나의 DataFrame으로 합치기
    result_df = pd.DataFrame({
        "globalStartName": [globalStartName],
        "globalEndName": [globalEndName],
        "globalTravelTime": [globalTravelTime],
        "globalDistance": [globalDistance],
        "globalStationCount": [globalStationCount],
        "fare": [fare],
        "cashFare": [cashFare]
    })

    stations_df["direction"] = stations_df["endSID"].astype(int) - stations_df["startID"].astype(int)
    stations_df["direction"] = stations_df["direction"].apply(lambda x: "하선" if x < 0 else "상선")
    stations_df["direction"] = pd.to_numeric(stations_df["direction"], errors="coerce")
    stations_df["direction"] = stations_df.apply(lambda row: "외선" if row["startID"] >= 200 and row["direction"] < 0 else "내선", axis=1)
    # 결과 DataFrame 출력
    display(result_df)
    print("\nDrive Info:")
    display(drive_info_df)
    print("\nStations Info:")
    display(stations_df)
    
metrojson()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 54
#      51     print("\nStations Info:")
#      52     display(stations_df)
# ---> 54 metrojson()
#
# Cell In[9], line 18, in metrojson()
#      15 data = res.json()
#      17 # DataFrame으로 만들 데이터 추출
# ---> 18 globalStartName = data["result"]["globalStartName"]
#      19 globalEndName = data["result"]["globalEndName"]
#      20 globalTravelTime = data["result"]["globalTravelTime"]
#
# KeyError: 'result'

# %%
import pandas as pd

time_table = pd.read_csv('/Users/yerin/AIB/udemy/dataset/서울교통공사_서울 도시철도 열차운행시각표_20230119.csv')
time_table
# Out:
# /var/folders/k7/kxwp0zb11c59md1f0chyrg000000gn/T/ipykernel_15937/2736216243.py:3: DtypeWarning: Columns (1,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   time_table = pd.read_csv('/Users/yerin/AIB/udemy/dataset/서울교통공사_서울 도시철도 열차운행시각표_20230119.csv')
#           고유번호      호선  역사코드        역사명 주중주말    방향  급행여부  열차코드    열차도착시간  \
# 0            1       2   211         성수  DAY    IN     0  2022       NaN
# 1            2       2   211         성수  DAY    IN     0  2026       NaN
# 2            3       2   211         성수  DAY    IN     0  2028       NaN
# 3            4       2   211         성수  DAY    IN     0  2030       NaN
# 4            5       2   211         성수  DAY    IN     0  2032       NaN
# ...        ...     ...   ...        ...  ...   ...   ...   ...       ...
# 526269  526274  의정부경전철  4603         범골  SAT  DOWN     0     7  07:02:30
# 526270  480563       8  2814       몽촌토성  SAT    UP     0  8030  07:44:30
# ...

# %%
time_table = time_table.drop(['호선', '열차코드', '열차도착시간', '고유번호'], axis=1)

# %%
import pickle

mapping = '/Users/yerin/AIB/udemy/preprocessing/mapping.pickle'
with open(mapping, 'rb') as fr:
    mapping = pickle.load(fr)

# %%
def string(df):
    for i in range(len(df)):
        df['열차코드'].loc[i] = str(df['열차코드'].loc[i])
        if len(df['열차코드'].loc[i]) < 4:
            df['열차코드'].loc[i] = "0"+df['열차코드'].loc[i]

string(time_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4         if len(df['열차코드'].loc[i]) < 4:
#       5             df['열차코드'].loc[i] = "0"+df['열차코드'].loc[i]
# ----> 7 string(time_table)
#
# NameError: name 'time_table' is not defined

# %%
def map_ebid_to_station_id(data):
    ebid_to_station_id = {}

    for station in data["result"]["station"]:
        ebid = station["arsID"]
        station_id = station["stationID"]
        
        if ebid in ebid_to_station_id:
            ebid_to_station_id[ebid] = [ebid_to_station_id[ebid], str(station_id)]
        else:
            ebid_to_station_id[ebid] = str(station_id)

    return ebid_to_station_id

# %%
mapping = map_ebid_to_station_id(dic)

# %%
len(mapping)
# Out:
# 758

# %%
import pickle

with open('/Users/yerin/AIB/udemy/preprocessing/mapping2.pickle','wb') as fw:
    pickle.dump(mapping, fw)

# %%
mapping
# Out:
# {'K118': ['1317', '1807'],
#  '123': '124',
#  'K117': ['1806', '191'],
#  'K209': '1509',
#  '122': '123',
#  '124': '125',
#  '640': '640',
#  '641': '641',
#  '121': '122',
#  '642': '642',
#  'K119': ['1316', '1808'],
#  '125': '126',
#  '211-3': '254',
#  '639': '639',
#  '211-2': '252',
#  '643': '643',
#  '542': '542',
#  '719': '719',
#  '541': '541',
#  'K120': ['1390', '1810'],
#  '720': '720',
#  '721': '721',
#  '126': '127',
#  '417': '417',
#  '211-4': '253',
#  '211-1': '251',
#  '638': '638',
#  'S122': '11333',
#  '644': '644',
#  '120': '121',
#  'S121': '11332',
#  '718': '718',
#  '722': '722',
#  '543': '543',
#  'S120': '11331',
#  '418': '418',
#  'K210': '1510',
#  'K116': '192',
#  '540': '540',
#  '723': '723',
#  '416': '416',
#  '208': '208',
#  '207': '207',
#  'K121': ['1811', '1315'],
#  '637': '637',
#  '645': '645',
#  '127': '199',
#  '724': '724',
#  '717': '717',
#  '209': '209',
#  '636': '636',
#  'S119': '11330',
#  '119': ['120', '1809'],
# ...

# %%
type([1, 2, 3])
# Out:
# list

# %%
for code in mapping:
    if type(mapping[code]) == list:
        print(code)
# Out:
# K118
# K117
# K119
# K120
# K121
# 119

# %%
mapping['148']
# Out:
# '148'

# %%
import pickle
mapping = '/Users/yerin/AIB/udemy/preprocessing/mapping2.pickle'

# load data
with open(mapping, 'rb') as fr:
    mapping = pickle.load(fr)

mapping
# Out:
# {'K118': ['1317', '1807'],
#  '123': '124',
#  'K117': ['1806', '191'],
#  'K209': '1509',
#  '122': '123',
#  '124': '125',
#  '640': '640',
#  '641': '641',
#  '121': '122',
#  '642': '642',
#  'K119': ['1316', '1808'],
#  '125': '126',
#  '211-3': '254',
#  '639': '639',
#  '211-2': '252',
#  '643': '643',
#  '542': '542',
#  '719': '719',
#  '541': '541',
#  'K120': ['1390', '1810'],
#  '720': '720',
#  '721': '721',
#  '126': '127',
#  '417': '417',
#  '211-4': '253',
#  '211-1': '251',
#  '638': '638',
#  'S122': '11333',
#  '644': '644',
#  '120': '121',
#  'S121': '11332',
#  '718': '718',
#  '722': '722',
#  '543': '543',
#  'S120': '11331',
#  '418': '418',
#  'K210': '1510',
#  'K116': '192',
#  '540': '540',
#  '723': '723',
#  '416': '416',
#  '208': '208',
#  '207': '207',
#  'K121': ['1811', '1315'],
#  '637': '637',
#  '645': '645',
#  '127': '199',
#  '724': '724',
#  '717': '717',
#  '209': '209',
#  '636': '636',
#  'S119': '11330',
#  '119': ['120', '1809'],
# ...

# %%
import pandas as pd

df = pd.read_csv('/Users/yerin/AIB/udemy/dataset/지하철 코드.csv', encoding='cp949')
df
# Out:
#     전철역코드   전철역명          전철명명(영문)    호선   외부코드    전철명명(중문) 전철명명(일문)
# 0    0244     용답           Yongdap  02호선  211-1          龍踏       龍踏
# 1    0245     신답            Sindap  02호선  211-2          新踏       新踏
# 2    0250     용두            Yongdu  02호선  211-3          龍頭       龍頭
# 3    0336    학여울        Hangnyeoul  03호선    346  Hangnyeoul   ハンニョウル
# 4    0428    삼각지          Samgakji  04호선    428         三角地      三角地
# ..    ...    ...               ...   ...    ...         ...      ...
# 768  0159    동묘앞           Dongmyo  01호선    127          東廟      東廟前
# 769  0200    까치산         Kkachisan  02호선  234-4         喜鵲山      カチ山
# 770  0201     시청         City Hall  02호선    201          市廳       市廳
# 771  0202  을지로입구  Euljiro 1(il)-ga  02호선    202       乙支路入口    乙支路入口
# 772  0300     대곡            Daegok   경의선   K322          大谷       大谷
#
# [773 rows x 7 columns]

# %%
df.query('외부코드=="211-1"')
# Out:
#   전철역코드 전철역명 전철명명(영문)    호선   외부코드 전철명명(중문) 전철명명(일문)
# 0  0244   용답  Yongdap  02호선  211-1       龍踏       龍踏

# %%
for code in mapping:
    for i in ['P176','P177', 'P171', 'P173', 'P169' 'P170' 'P174' 'P172' 'P168' 'D7','D4','D5','D6','D8','D9']:
        if code == i:
            print(code)

# %%
for code in mapping:
    print(code)
# Out:
# K118
# 123
# K117
# K209
# 122
# 124
# 640
# 641
# 121
# 642
# K119
# 125
# 211-3
# 639
# 211-2
# 643
# 542
# 719
# 541
# K120
# 720
# 721
# 126
# 417
# 211-4
# 211-1
# 638
# S122
# 644
# 120
# S121
# 718
# 722
# 543
# S120
# 418
# K210
# K116
# 540
# 723
# 416
# 208
# 207
# K121
# 637
# 645
# 127
# 724
# 717
# 209
# 636
# S119
# 119
# 206
# 539
# 635
# 419
# 544
# 725
# 128
# 646
# 716
# 421
# 647
# S116
# 420
# K115
# 210
# 205
# 537
# S118
# 634
# 415
# 538
# 422
# 118
# 726
# S117
# 211
# 129
# 536
# P122
# K211
# K122
# 648
# 545
# S115
# 715
# 333
# 332
# 633
# 535
# 204
# 727
# 212
# 334
# 329
# 130
# 534
# S114
# 414
# 330
# 331
# 203
# 423
# 632
# 117
# 335
# 328
# K114
# 714
# 213
# 728
# 546
# 131
# S113
# 424
# 413
# 202
# K212
# 214
# 116
# 533
# 412
# 631
# 327
# 132
# 713
# 336
# P123
# 425
# 201
# 411
# S112
# K113
# 729
# 810
# 630
# 730
# K123
# 133
# K213
# 532
# 410
# P313
# 426
# S111
# 929
# 811
# 547
# A01
# 928
# 712
# 629
# 731
# 243
# 337
# 326
# 531
# D04
# ...

# %%
mapping
# Out:
# {'K118': ['1317', '1807'],
#  '123': '124',
#  'K117': ['1806', '191'],
#  'K209': '1509',
#  '122': '123',
#  '124': '125',
#  '640': '640',
#  '641': '641',
#  '121': '122',
#  '642': '642',
#  'K119': ['1316', '1808'],
#  '125': '126',
#  '211-3': '254',
#  '639': '639',
#  '211-2': '252',
#  '643': '643',
#  '542': '542',
#  '719': '719',
#  '541': '541',
#  'K120': ['1390', '1810'],
#  '720': '720',
#  '721': '721',
#  '126': '127',
#  '417': '417',
#  '211-4': '253',
#  '211-1': '251',
#  '638': '638',
#  'S122': '11333',
#  '644': '644',
#  '120': '121',
#  'S121': '11332',
#  '718': '718',
#  '722': '722',
#  '543': '543',
#  'S120': '11331',
#  '418': '418',
#  'K210': '1510',
#  'K116': '192',
#  '540': '540',
#  '723': '723',
#  '416': '416',
#  '208': '208',
#  '207': '207',
#  'K121': ['1811', '1315'],
#  '637': '637',
#  '645': '645',
#  '127': '199',
#  '724': '724',
#  '717': '717',
#  '209': '209',
#  '636': '636',
#  'S119': '11330',
#  '119': ['120', '1809'],
# ...

# %%
['1415',
 '신창',
 '쌍용',
 '탕정',
 '천안',
 '봉명',
 '배방',
 '아산',
 '두정',
 '강남',
 '신사',
 '논현',
 '신논현',
 '양재',
 '양재시민의숲']
# Out:
# ['온양온천',
#  '신창',
#  '쌍용',
#  '탕정',
#  '천안',
#  '봉명',
#  '배방',
#  '아산',
#  '두정',
#  '강남',
#  '신사',
#  '논현',
#  '신논현',
#  '양재',
#  '양재시민의숲']

# %%
yunsu = {
    '836': '11416', '837': '11417', '839': '11419', '840': '11420', '838': '11418', '845': '11425', '846': '11427',
    '847': '11428', '848': '11429', '849': '11430', '850': '11431', '701': '11432', '702': '11433', '841': '11421',
    '842': '11422', '843': '11423', '844': '11424', '690': '11511', '691': '11512', '692': '11513', '693': '11514',
    '694': '11515', '695': '11516', '696': '11517', '697': '11518', '698': '11519', '699': '11520', 'Y110': '1701',
    'Y111': '1702', 'Y112': '1703', 'Y113': '1704', 'Y114': '1705', 'Y115': '1706', 'Y116': '1707', 'Y117': '1708',
    'Y118': '1709', 'Y119': '1710', 'Y120': '1711', 'Y121': '1712', 'Y123': '1713', 'Y125': '1714', 'Y126': '1715',
    '941': '11321', '942': '11322', '943': '11323', '944': '11324', '945': '11325', '946': '11326', '947': '11327', 
    '948': '11328', '949': '11329', '950': '11330', '951': '11331', '952': '11332', '953': '11333', 'P130': '1820',
    'P119': '1808', 'P121': '1811', 'P122': '1812', 'P127': '1817', 'P129': '1819', 'P131': '1821', 'P133': '1823',
    'P139': '1829', 'P116': '1809', 'P117': '1806', 'P123': '1813', 'P125': '1815', 'P135': '1825', 'P136': '1826',
    'P138': '1828', 'P128': '1818', 'P134': '1824', 'P120': '1810', 'P132': '1822', 'P118': '1807', 'P126': '1816',
    'P124': '1814', 'P140': '1830', 'P137': '1827',
    'K111': '198', 'K117': '191', 'K336': '1630', 'K135': '1302', 'K136': '1301', 'K110': '1318', 'K116': '192',
    'K314': '1609', 'K315': '1612', 'K330': '1625', 'K122': '1314', 'K126': '1310', 'K137': '1300', 'K119': '1316',
    'K316': '1613', 'K318': '1615', 'K112': '197', 'K121': '1315', 'K132': '1304', 'K113': '196', 'K319': '1635',
    'K326': '1622', 'K327': '1623', 'K328': '1636', 'K331': '1626', 'K138': '1299', 'P313': '1610', 'K826': '1606',
    'K312': '1607', 'K323': '1619', 'K329': '1624', 'K334': '1628', 'K123': '1313', 'K124': '1312',
    'K125': '1311', 'K128': '1308', 'K129': '1307', 'K130': '1306', 'K131': '1305', 'K133': '1303', 'K134': '1394',
    'K335': '1629', 'K114': '195', 'K115': '193', 'P312': '1611', 'K320': '1616', 'K333': '1627', 'K336': '1631',
    'K118': '1317', 'K120': '1390', 'K127': '1309', 'K313': '1608', 'K325': '1621', 'K317': '1614', 'K324': '1620',
    'K321': '1617', 'K322': '1618', "234-4":'264', "234-3":'263', "234-2":'262', "234-1":'261', "211-4":'253', "211-3":'254',
    "211-2":'252', "211-1":'251', "P549": '569', "P550":'570', "P551":'571', "P552":'572', "P553":'573', "P554":'574', "P555":'575'}

# %%
import pickle
mapping_path = '/Users/yerin/AIB/udemy/preprocessing/mapping.pickle'

with open(mapping_path, 'rb') as f:
    mapping = pickle.load(f)

# %%
swapped_dict = {v: k for k, v in mapping.items()}

# %%
swapped_dict
# Out:
# {'211-1': '0244',
#  '211-2': '0245',
#  '211-3': '0250',
#  '346': '0336',
#  '428': '0428',
#  '429': '0429',
#  'K111': '1008',
#  'K117': '1014',
#  '836': '103C',
#  '837': '104C',
#  'K336': '1285',
#  '441': '1456',
#  'P144': '1703',
#  '412': '0412',
#  '417': '0417',
#  'K210': '102C',
#  'K221': '1030',
#  'K135': '1217',
#  'K136': '1218',
#  'P176': '1407',
#  '435': '1450',
#  '437': '1452',
#  '440': '1455',
#  '443': '1458',
#  'K413': '1504',
#  '320': '0310',
#  '329': '0319',
#  '349': '0339',
#  '415': '0415',
#  '425': '0425',
#  'K110': '100C',
#  'K116': '1013',
#  'K314': '1264',
#  'K315': '1265',
#  'K330': '1279',
#  'P177': '1408',
#  'K411': '1502',
#  'K419': '1510',
#  'P142': '1702',
#  'P145': '1704',
#  'P147': '1706',
#  'P148': '1707',
#  'P149': '1708',
#  'P150': '1709',
#  'P153': '1711',
#  'P144-1': '1750',
#  '455': '1761',
#  '144': '1802',
#  'K211': '1847',
#  'K264': '1883',
#  '234-2': '0248',
#  '330': '0320',
#  '337': '0327',
# ...

# %%
import pickle
mapping_path = '/Users/yerin/AIB/udemy/preprocessing/mapping_final.pickle'

with open(mapping_path, 'rb') as f:
    mapping = pickle.load(f)

# %%
df['경로코드'] = df['외부코드'].replace(mapping)

# %%
df.isnull().sum()
# Out:
# 전철역코드        0
# 전철역명         0
# 전철명명(영문)     0
# 호선           0
# 외부코드         0
# 전철명명(중문)    31
# 전철명명(일문)    41
# 경로코드         0
# dtype: int64

# %%
df.to_csv('/Users/yerin/AIB/udemy/dataset/경로코드_update.csv')

# %%
import json
from flask import Blueprint, render_template, request
import pandas as pd
import requests
from workalendar.asia import SouthKorea
from datetime import date
from datetime import datetime, time
import numpy as np
import pickle

def metrojson(SID, EID):

    SID = str(SID)
    EID = str(EID)
    Sopt = '1'   # 최단거리(1) 또는 최소환승(2) 설정
    apiKey = "VMlJA4GzIlpVQkHARsMsz6uOKDrPKxiHBCfYXoz6ufo"

    url = f'https://api.odsay.com/v1/api/subwayPath?lang=0&CID=1000&SID={SID}&EID={EID}&Sopt={Sopt}&apiKey={apiKey}'
    
    res = requests.get(url)
    data = res.json()

    # DataFrame으로 만들 데이터 추출
    globalStartName = data["result"]["globalStartName"]
    globalEndName = data["result"]["globalEndName"]
    globalTravelTime = data["result"]["globalTravelTime"]
    globalDistance = data["result"]["globalDistance"]
    globalStationCount = data["result"]["globalStationCount"]
    fare = data["result"]["fare"]
    cashFare = data["result"]["cashFare"]
    driveInfoSet = data["result"]["driveInfoSet"]
    stationSet = data["result"]["stationSet"]

    # 'driveInfo'와 'stations' 리스트를 DataFrame으로 변환
    drive_info_df = pd.DataFrame(driveInfoSet["driveInfo"])
    stations_df = pd.DataFrame(stationSet["stations"])
    
    # 결과 데이터를 하나의 DataFrame으로 합치기
    result_df = pd.DataFrame({
        "globalStartName": [globalStartName],
        "globalEndName": [globalEndName],
        "globalTravelTime": [globalTravelTime],
        "globalDistance": [globalDistance],
        "globalStationCount": [globalStationCount],
        "fare": [fare],
        "cashFare": [cashFare]
    })
    
    return result_df

# %%
df[df['전철역명']=='서울역']['경로코드'].iloc[2]
# Out:
# 4001

# %%
df['경로코드'] = df['경로코드'].astype('str')

# %%
df.to_csv('/Users/yerin/AIB/udemy/dataset/경로코드_update.csv')

# %%
df[df['전철역명']=='신설동']['경로코드'].iloc[0]
# Out:
# '253'

# %%
def metrojson(SID, EID):

    SID = str(SID)
    EID = str(EID)
    Sopt = '1'   # 최단거리(1) 또는 최소환승(2) 설정
    apiKey = "VMlJA4GzIlpVQkHARsMsz6uOKDrPKxiHBCfYXoz6ufo"

    url = f'https://api.odsay.com/v1/api/subwayPath?lang=0&CID=1000&SID={SID}&EID={EID}&Sopt={Sopt}&apiKey={apiKey}'
    
    res = requests.get(url)
    data = res.json()

    # DataFrame으로 만들 데이터 추출
    globalStartName = data["result"]["globalStartName"]
    globalEndName = data["result"]["globalEndName"]
    globalTravelTime = data["result"]["globalTravelTime"]
    globalDistance = data["result"]["globalDistance"]
    globalStationCount = data["result"]["globalStationCount"]
    fare = data["result"]["fare"]
    cashFare = data["result"]["cashFare"]
    driveInfoSet = data["result"]["driveInfoSet"]
    stationSet = data["result"]["stationSet"]

    # 'driveInfo'와 'stations' 리스트를 DataFrame으로 변환
    drive_info_df = pd.DataFrame(driveInfoSet["driveInfo"])
    stations_df = pd.DataFrame(stationSet["stations"])
    
    # 결과 데이터를 하나의 DataFrame으로 합치기
    result_df = pd.DataFrame({
        "globalStartName": [globalStartName],
        "globalEndName": [globalEndName],
        "globalTravelTime": [globalTravelTime],
        "globalDistance": [globalDistance],
        "globalStationCount": [globalStationCount],
        "fare": [fare],
        "cashFare": [cashFare]
    })

    def get_direction(row):
        if row["startName"] == "시청" and row["endName"] == "충정로":
            return "외선"
        elif (200 <= row["startID"] <= 299) and (200 <= row["endSID"] <= 299):
            return "내선" if row["startID"] < row["endSID"] else "외선"
        else:
            return "하선" if row["startID"] > row["endSID"] else "상선"
    stations_df["direction"] = stations_df.apply(get_direction, axis=1)

    # 원하는 결과 컬럼들만 선택하여 새로운 DataFrame을 생성
    final_stations_df = stations_df[["startID", "endSID", "direction"]]

    return final_stations_df, drive_info_df

# %%
df = pd.read_csv('/Users/yerin/AIB/udemy/dataset/경로코드_update.csv')

# %%
SID = df[df['전철역명']=="서울역"]['경로코드'].iloc[0]
EID = df[df['전철역명']=="신설동"]['경로코드'].iloc[0]

df_stations, drive_info_df  = metrojson('426', '210')

# %%
df_stations
# Out:
#    startID  endSID direction
# 0      426     425        하선
# 1      425     424        하선
# 2      424     423        하선
# 3      423     422        하선
# 4      205     206        내선
# 5      206     207        내선
# 6      207     208        내선
# 7      208     209        내선
# 8      209     210        내선

# %%
drive_info_df
# Out:
#   laneID laneName  startName  stationCount  wayCode wayName
# 0      4      4호선        서울역             4        1      진접
# 1      2      2호선  동대문역사문화공원             5        2    내선순환

# %%
counts = [drive_info_df['laneName'][i] for i in range(len(drive_info_df))]
counts
# Out:
# [4, 5]

# %%
df
# Out:
#      Unnamed: 0 전철역코드   전철역명          전철명명(영문)    호선   외부코드    전철명명(중문)  \
# 0             0  0244     용답           Yongdap  02호선  211-1          龍踏
# 1             1  0245     신답            Sindap  02호선  211-2          新踏
# 2             2  0250     용두            Yongdu  02호선  211-3          龍頭
# 3             3  0336    학여울        Hangnyeoul  03호선    346  Hangnyeoul
# 4             4  0428    삼각지          Samgakji  04호선    428         三角地
# ..          ...   ...    ...               ...   ...    ...         ...
# 768         768  0159    동묘앞           Dongmyo  01호선    127          東廟
# 769         769  0200    까치산         Kkachisan  02호선  234-4         喜鵲山
# 770         770  0201     시청         City Hall  02호선    201          市廳
# 771         771  0202  을지로입구  Euljiro 1(il)-ga  02호선    202       乙支路入口
# 772         772  0300     대곡            Daegok   경의선   K322          大谷
#
#     전철명명(일문)  경로코드
# 0         龍踏   251
# 1         新踏   252
# 2         龍頭   254
# 3     ハンニョウル   346
# ...

# %%
# Out:
# 0    425
# 1    424
# 2    423
# 3    422
# 4    206
# 5    207
# 6    208
# 7    209
# 8    210
# Name: endSID, dtype: int64

# %%
ls = df_stations['endSID']
dic = {}
for i in range(len(df_stations)):
    code = str(df_stations['startID'][i])
    congestion = ls[i]
    dic[df[df['경로코드']==code]['전철역명'].iloc[0]] = congestion

# %%
stations = [df[df['경로코드']==str(df_stations['startID'][i])]['전철역명'].iloc[0] for i in range(len(df_stations))]
stations
# Out:
# ['서울역', '회현', '명동', '충무로', '동대문역사문화공원', '신당', '상왕십리', '왕십리', '한양대']

# %%
split_stations = []
for count in counts:
    split_stations.append(stations[:count])
    del stations[:count]

# %%
split_stations
# Out:
# [['서울역', '회현', '명동', '충무로'], ['동대문역사문화공원', '신당', '상왕십리', '왕십리', '한양대']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  773 non-null    int64
#  1   전철역코드       773 non-null    object
#  2   전철역명        773 non-null    object
#  3   전철명명(영문)    773 non-null    object
#  4   호선          773 non-null    object
#  5   외부코드        773 non-null    object
#  6   전철명명(중문)    742 non-null    object
#  7   전철명명(일문)    732 non-null    object
#  8   경로코드        773 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 54.5+ KB

# %%
df[df['전철역명']=="신설동"]['경로코드']
# Out:
# 229      253
# 753    11333
# 765      127
# Name: 경로코드, dtype: object

# %%
new_df = df[df["호선"].str.match(r'^(0[1-9]호선|신분당선)$')]
new_df.to_csv('/Users/yerin/AIB/udemy/dataset/1_9_신분당선.csv')

# %%
"서울역"[-1]
# Out:
# '역'

# %%
"송내역"[:-1]
# Out:
# '송내'
